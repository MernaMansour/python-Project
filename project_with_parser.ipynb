# %%
import os 
import shutil as sh
class File_handling:
  #1sr function for searching
  def Search_file(path):
    exists=os.path.exists(path)
    if exists==True:
        print("the file exists")
    else:
        print("the file does not extist")
  #2nd function for renaming
  def Rename_file(original_name,new_name):
    os.rename(original_name,new_name)
  #3rd function for modifing
  def Modify_content(path,original_content,new_content):
    with open(path, "r") as file:
      content = file.read()
      modified_content = content.replace(original_content,new_content)
    with open(path, "w") as file:
      file.write(modified_content)
    print("File content modified successfully")
  #4th function for coping
  def Copy_files(file_names,original_path,target_path):
    for file_name in file_names:
        full_original_path = os.path.join(original_path, file_name)
        full_target_path = os.path.join(target_path, file_name)
        sh.copyfile(full_original_path, full_target_path)
        print(f"Copied {file_name} to {target_path}")
  #5th function for moving
  def Move_file(file_names,original_path,target_path):
    for file_name in file_names:
        full_original_path = os.path.join(original_path, file_name)
        full_target_path = os.path.join(target_path, file_name)
        sh.move(full_original_path, full_target_path)
        print(f"Moved {file_name} to {target_path}")
  #6th function search by findig the firector
    def find_file_directory(first_path, file_name):
        found = False
        for root, dirs, files in os.walk(first_path):
            if file_name in files:
                print(f"File found in directory: {root}")
                found = True
                break
        if not found:
            print("File not found in the directory")

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser(description="File Operations: Search, Rename, Modify, Copy, Move, Find")
    parser1 = parser.add_subparsers(dest='operation', help='File operations')

    # Search
    parser_search = parser1.add_parser('search', help='Search for a file')
    parser_search.add_argument('path', type=str, help='The path of the file to search')

    # Rename
    parser_rename = parser1.add_parser('rename', help='Rename a file')
    parser_rename.add_argument('original_name', type=str, help='The original file name')
    parser_rename.add_argument('new_name', type=str, help='The new file name')

    # Modify
    parser_modify = parser1.add_parser('modify', help='Modify content in a file')
    parser_modify.add_argument('path', type=str, help='The path of the file to modify')
    parser_modify.add_argument('original_content', type=str, help='The content to be replaced')
    parser_modify.add_argument('new_content', type=str, help='The new content to insert')

    # Copy
    parser_copy = parser1.add_parser('copy', help='Copy files')
    parser_copy.add_argument('file_names', nargs='+', help='The names of the files to copy')
    parser_copy.add_argument('original_path', type=str, help='The original path of the files')
    parser_copy.add_argument('target_path', type=str, help='The target path to copy the files to')

    # Move
    parser_move = parser1.add_parser('move', help='Move files')
    parser_move.add_argument('file_names', nargs='+', help='The names of the files to move')
    parser_move.add_argument('original_path', type=str, help='The original path of the files')
    parser_move.add_argument('target_path', type=str, help='The target path to move the files to')

    # Find directory
    parser_find = parser1.add_parser('find', help='Find file in directory')
    parser_find.add_argument('first_directory', type=str, help='The directory to start searching from')
    parser_find.add_argument('file_name', help='The name of the file to find')
    # Parse the arguments
    args = parser.parse_args()

    # Create an object of File_handling class
    Files_operations = File_handling()

    # Check the operation
    if args.operation == 'search':
        Files_operations.Search_file(args.path)
    elif args.operation == 'rename':
        Files_operations.Rename_file(args.original_name, args.new_name)
    elif args.operation == 'modify':
        Files_operations.Modify_content(args.path, args.original_content, args.new_content)
    elif args.operation == 'copy':
        Files_operations.Copy_files(args.file_names, args.original_path, args.target_path)
    elif args.operation == 'move':
        Files_operations.Move_file(args.file_names, args.original_path, args.target_path)
    elif args.operation == 'find':
        Files_operations.Find_file_directory(args.first_directory, args.file_name)
    else:
        parser.print_help()
# Out:
# usage: ipykernel_launcher.py [-h] {search,rename,modify,copy,move,find} ...
# ipykernel_launcher.py: error: argument operation: invalid choice: 'C:\\Users\\user\\AppData\\Roaming\\jupyter\\runtime\\kernel-9a1a7682-265d-4747-ac60-ee8f8a610feb.json' (choose from 'search', 'rename', 'modify', 'copy', 'move', 'find')
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File ~\anaconda3\lib\argparse.py:1857, in ArgumentParser.parse_known_args(self, args, namespace)
#    1856 try:
# -> 1857     namespace, args = self._parse_known_args(args, namespace)
#    1858 except ArgumentError:
#
# File ~\anaconda3\lib\argparse.py:2069, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2068 # consume any positionals following the last Optional
# -> 2069 stop_index = consume_positionals(start_index)
#    2071 # if we didn't consume all the argument strings, there were extras
#
# ...
